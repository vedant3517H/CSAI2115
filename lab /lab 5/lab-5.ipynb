# %% [markdown]
# Using Python language do the exploratory data analysis of dataset

# %%
# IMPORT NECESSASRY MODULES

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ADD YOUR DATAFRAME

df = pd.read_csv('matches.csv')

# %% [markdown]
# todo:- (in class)
#
# Evaluate frequency of most man of the match awards<br>
# Extract top 10 players with most motm awards<br>
# Extract top 5 players with most motm awards<br>
# Draw bar plot of top 5 most motm award players<br>
# Draw violin plot of top 5 most motm award players<br>
# Evaluate frequency of result column<br>
# Find number of toss win with respect to each team<br>
# Extract the record where a team won batting first<br>
# Make the histogram of win by run column<br>
# Find out the number of wins wrt each team after batting first<br>
# Make the bar plot for top 3 teams with most wins after getting first<br>

# %%
df['player_of_match'].value_counts()
# Out:
# player_of_match
# AB de Villiers       25
# CH Gayle             22
# RG Sharma            19
# DA Warner            18
# V Kohli              18
#                      ..
# NV Ojha               1
# KV Sharma             1
# Washington Sundar     1
# PD Collingwood        1
# Shahbaz Ahmed         1
# Name: count, Length: 291, dtype: int64

# %%
df['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
df['player_of_match'].value_counts().head(5)
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# Name: count, dtype: int64

# %%
df['player_of_match'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='player_of_match'>

# %%
sns.violinplot(x=df['player_of_match'].value_counts().head(5))
# Out:
# <Axes: xlabel='count'>

# %%
df['result'].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
df['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 143
# Kolkata Knight Riders          122
# Chennai Super Kings            122
# Rajasthan Royals               120
# Royal Challengers Bangalore    113
# Sunrisers Hyderabad             88
# Kings XI Punjab                 85
# Delhi Daredevils                80
# Delhi Capitals                  50
# Deccan Chargers                 43
# Punjab Kings                    24
# Gujarat Titans                  22
# Pune Warriors                   20
# Lucknow Super Giants            19
# Gujarat Lions                   15
# Kochi Tuskers Kerala             8
# Royal Challengers Bengaluru      8
# Rising Pune Supergiants          7
# Rising Pune Supergiant           6
# Name: count, dtype: int64

# %%
df[(df['toss_decision'] == 'bat') & (df['winner'] == df['team1'])]
# Out:
#            id   season           city        date match_type player_of_match  \
# 2      335984  2007/08          Delhi  2008-04-19     League     MF Maharoof
# 4      335986  2007/08        Kolkata  2008-04-20     League       DJ Hussey
# 5      335987  2007/08         Jaipur  2008-04-21     League       SR Watson
# 11     335993  2007/08        Chennai  2008-04-26     League        JDP Oram
# 13     335995  2007/08     Chandigarh  2008-04-27     League       SM Katich
# ...       ...      ...            ...         ...        ...             ...
# 1036  1422131     2024  Visakhapatnam  2024-03-31     League        KK Ahmed
# 1039  1422134     2024  Visakhapatnam  2024-04-03     League       SP Narine
# 1044  1422139     2024        Lucknow  2024-04-07     League     Yash Thakur
# 1064  1426279     2024      Hyderabad  2024-04-25     League      RM Patidar
# 1073  1426288     2024      Hyderabad  2024-05-02     League         B Kumar
#
# ...

# %%
df['target_runs'].hist()
# Out:
# <Axes: >

# %%
df[(df['result'] == 'win') & (df['toss_decision'] == 'bat')]['winner'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
wins_after_batting_first = df[df['winner'] == df['team1']]

wins_count = wins_after_batting_first['team1'].value_counts()

top_3_teams = wins_count.head(3)

plt.figure(figsize=(10, 6))
top_3_teams.plot(kind='bar', color='skyblue')
plt.title('Top 3 Teams with Most Wins After Batting First')
plt.xlabel('Team')
plt.ylabel('Number of Wins')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 11 todo by yourself

# %%
# win % by team


team_wins = df[df['winner'] == df['team1']].groupby('team1').size()
team_matches = df.groupby('team1').size()
win_percentage = (team_wins / team_matches * 100).fillna(0)
print(win_percentage)
# Out:
# team1
# Chennai Super Kings            58.593750
# Deccan Chargers                33.333333
# Delhi Capitals                 56.097561
# Delhi Daredevils               44.705882
# Gujarat Lions                  31.250000
# Gujarat Titans                 52.380952
# Kings XI Punjab                46.739130
# Kochi Tuskers Kerala           42.857143
# Kolkata Knight Riders          53.719008
# Lucknow Super Giants           69.565217
# Mumbai Indians                 56.910569
# Pune Warriors                  26.086957
# Punjab Kings                   35.483871
# Rajasthan Royals               54.455446
# Rising Pune Supergiant         71.428571
# Rising Pune Supergiants        28.571429
# Royal Challengers Bangalore    48.888889
# Royal Challengers Bengaluru    44.444444
# Sunrisers Hyderabad            51.162791
# dtype: float64

# %%
#Analyze Match Outcomes by Venue

venue_outcome = df.groupby('venue')['result'].value_counts().unstack().fillna(0)
print(venue_outcome)
# Out:
# result                                              no result  runs  tie  \
# venue
# Arun Jaitley Stadium                                      0.0   7.0  1.0
# Arun Jaitley Stadium, Delhi                               0.0   9.0  0.0
# Barabati Stadium                                          0.0   4.0  0.0
# Barsapara Cricket Stadium, Guwahati                       0.0   2.0  0.0
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cr...        1.0   7.0  0.0
# Brabourne Stadium                                         0.0   6.0  0.0
# Brabourne Stadium, Mumbai                                 0.0   8.0  0.0
# Buffalo Park                                              0.0   2.0  0.0
# De Beers Diamond Oval                                     0.0   1.0  0.0
# Dr DY Patil Sports Academy                                0.0   7.0  0.0
# Dr DY Patil Sports Academy, Mumbai                        0.0  10.0  0.0
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...        0.0   7.0  0.0
# ...

# %%
# Evaluate Toss Decision Effectiveness

toss_decision_win = df[df['toss_winner'] == df['team1']].groupby('toss_decision')['winner'].value_counts().unstack().fillna(0)
print(toss_decision_win)
# Out:
# winner         Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# toss_decision
# bat                           44.0              5.0            13.0
# field                         10.0              4.0             0.0
#
# winner         Delhi Daredevils  Gujarat Lions  Gujarat Titans  \
# toss_decision
# bat                        17.0            0.0             9.0
# field                      13.0            4.0             0.0
#
# winner         Kings XI Punjab  Kochi Tuskers Kerala  Kolkata Knight Riders  \
# toss_decision
# bat                       16.0                   0.0                   33.0
# field                     23.0                   3.0                   23.0
#
# winner         Lucknow Super Giants  Mumbai Indians  Pune Warriors  \
# toss_decision
# bat                             6.0            36.0            4.0
# field                           0.0            26.0            3.0
#
# ...

# %%
# Find Average Target Runs and Overs by Season

avg_target = df.groupby('season')['target_runs'].mean()
avg_overs = df.groupby('season')['target_overs'].mean()
print(avg_target)
print(avg_overs)
# Out:
# season
# 2007/08    159.775862
# 2009       148.807018
# 2009/10    165.783333
# 2011       154.041667
# 2012       158.540541
# 2013       156.894737
# 2014       162.383333
# 2015       164.706897
# 2016       160.783333
# 2017       165.406780
# 2018       170.200000
# 2019       167.733333
# 2020/21    170.500000
# 2021       160.316667
# 2022       172.121622
# 2023       183.397260
# 2024       190.591549
# Name: target_runs, dtype: float64
# season
# 2007/08    19.482759
# 2009       19.529825
# 2009/10    20.000000
# 2011       19.722222
# 2012       19.891892
# 2013       19.842105
# 2014       19.700000
# 2015       19.275862
# 2016       19.416667
# 2017       19.762712
# 2018       19.516667
# 2019       19.750000
# 2020/21    20.000000
# 2021       20.000000
# 2022       20.000000
# 2023       19.876712
# 2024       19.943662
# Name: target_overs, dtype: float64

# %%
# Analyze Matches by Match Type

match_type_stats = df['match_type'].value_counts()
print(match_type_stats)
# Out:
# match_type
# League                1029
# Final                   17
# Qualifier 1             14
# Qualifier 2             14
# Eliminator              11
# Semi Final               6
# Elimination Final        3
# 3rd Place Play-Off       1
# Name: count, dtype: int64

# %%
# Find the Distribution of Umpires

umpire1_dist = df['umpire1'].value_counts()
umpire2_dist = df['umpire2'].value_counts()
print(umpire1_dist)
print(umpire2_dist)
# Out:
# umpire1
# AK Chaudhary             115
# HDPK Dharmasena           79
# KN Ananthapadmanabhan     59
# CB Gaffaney               53
# Asad Rauf                 51
#                         ...
# AV Jayaprakash             2
# K Srinath                  2
# AG Wharf                   2
# SL Shastri                 1
# SJA Taufel                 1
# Name: count, Length: 62, dtype: int64
# umpire2
# S Ravi           83
# VK Sharma        61
# C Shamshuddin    60
# Nitin Menon      54
# SJA Taufel       54
#                  ..
# JD Cloete         1
# SJ Davis          1
# Subroto Das       1
# BF Bowden         1
# SD Fry            1
# Name: count, Length: 62, dtype: int64

# %%
# Identify High-Scoring Matches 

high_scoring_matches = df[df['target_runs'] > 200]
print(high_scoring_matches)
# Out:
#            id   season        city        date match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18     League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19     League       MEK Hussey
# 7      335989  2007/08     Chennai  2008-04-23     League        ML Hayden
# 8      335990  2007/08   Hyderabad  2008-04-24     League        YK Pathan
# 31     336014  2007/08   Hyderabad  2008-05-11     League       SC Ganguly
# ...       ...      ...         ...         ...        ...              ...
# 1082  1426297     2024   Ahmedabad  2024-05-10     League     Shubman Gill
# 1086  1426302     2024       Delhi  2024-05-14     League         I Sharma
# 1088  1426305     2024      Mumbai  2024-05-17     League         N Pooran
# 1089  1426306     2024   Bengaluru  2024-05-18     League     F du Plessis
# 1090  1426307     2024   Hyderabad  2024-05-19     League  Abhishek Sharma
#
#                                                   venue  \
# ...

# %%
# Determine the Most Common Result Margin

result_margin_freq = df['result_margin'].value_counts()
print(result_margin_freq)
# Out:
# result_margin
# 6.0      131
# 7.0      130
# 5.0      109
# 8.0       85
# 4.0       74
#         ...
# 76.0       1
# 53.0       1
# 105.0      1
# 66.0       1
# 106.0      1
# Name: count, Length: 98, dtype: int64

# %%
# Analyze Matches by City

city_match_stats = df['city'].value_counts()
print(city_match_stats)
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
# Evaluate the Frequency of Super Overs

super_over_count = df['super_over'].value_counts()
print(super_over_count)
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='super_over')
plt.title('Frequency of Super Overs')
plt.xlabel
# Out:
# super_over
# N    1081
# Y      14
# Name: count, dtype: int64
# <function matplotlib.pyplot.xlabel(xlabel: 'str', fontdict: 'dict[str, Any] | None' = None, labelpad: 'float | None' = None, *, loc: "Literal['left', 'center', 'right'] | None" = None, **kwargs) -> 'Text'>

# %% [markdown]
# ----

# %%
# Make-bar chart, histograms, violin plot, box diagram
data = pd.read_csv("median_gamma_power.csv")
df = pd.DataFrame(data)

plt.figure(figsize=(15, 10))

# 1. Bar Chart
plt.subplot(2, 2, 1)
df[['Group', 'Gamma_All']].groupby('Group').mean().plot(kind='bar', ax=plt.gca())
plt.title('Bar Chart of Gamma_All by Group')
plt.grid(True)

# 2. Histogram
plt.subplot(2, 2, 2)
plt.hist(df['Gamma_All'], bins=5, edgecolor='black')
plt.title('Histogram of Gamma_All')
plt.grid(True)

# 3. Violin Plot
plt.subplot(2, 2, 3)
sns.violinplot(x='Group', y='Gamma_All', data=df, ax=plt.gca())
plt.title('Violin Plot of Gamma_All by Group')
plt.grid(True)

# 4. Box Plot
plt.subplot(2, 2, 4)
sns.boxplot(x='Group', y='Gamma_All', data=df, ax=plt.gca())
plt.title('Box Plot of Gamma_All by Group')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
data = pd.read_csv("median_alpha_power.csv")
df = pd.DataFrame(data)

plt.figure(figsize=(15, 10))

# 1. Bar Chart
plt.subplot(2, 2, 1)
df.groupby('Group')['Alpha'].mean().plot(kind='bar', ax=plt.gca())
plt.title('Bar Chart of Alpha by Group')
plt.grid(True)

# 2. Histogram
plt.subplot(2, 2, 2)
plt.hist(df['Alpha'], bins=5, edgecolor='black')
plt.title('Histogram of Alpha')
plt.grid(True)

# 3. Violin Plot
plt.subplot(2, 2, 3)
sns.violinplot(x='Group', y='Alpha', data=df, ax=plt.gca())
plt.title('Violin Plot of Alpha by Group')
plt.grid(True)

# 4. Box Plot
plt.subplot(2, 2, 4)
sns.boxplot(x='Group', y='Alpha', data=df, ax=plt.gca())
plt.title('Box Plot of Alpha by Group')
plt.grid(True)

plt.tight_layout()
plt.show()
